# %%
# https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/cf22c46b-1dc5-4dc9-b34b-6988f21aae31
import requests
id1 = "4a095ca8-c8e9-4833-9691-ced6995fa34a" #spread 1
id2 = "b7b6ce35-5326-46cc-9f84-f2db9b883930" #spread 2
id3 = "028eab9f-0821-4a60-9d76-7ceb9665f47b" #spread 3
url = 'https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/' + id2
headers = {'Authorization': 'Bearer eyJraWQiOiJ4M3NhZjFZTkNsRGwyVDljemdCR01ybnVVMlJlNDNjb1E1UGxYMWgwb2tBPSIsImFsZyI6IlJTMjU2In0.....CEQV8q0DDrfSa1qe_aGc3qHPmx9DwDUALwBaf0jh9WpNYLsr8Thuq8CygIEm91XAWhjIouYPWJfewoR6sgL7-1XJfwZtIgPkTvgFWZ5iNgaFojdXVkvgHi2iJOblSOFhGTwoFbX582azhuXWEUmaxVePrxj5pVFEkcRFMChsPbnxF5R66S8khqU9D4qg2FHz7t9Sj5zt0BwOYg9eR1i3kGGs6rRXv-uNX_JtHxlw7okGUab_Wlm1vMNuxlJPlSK4FPi6TSTD5UGp_mRqrs5WIGmJWQOci-fuW6c8b8IraFvVA04yQRNTNgb7VLtoOgQBctCE9EqVzNJHyjzcgFrUJQ'}
r = requests.get(url, headers=headers)

# %%
print(r.json())
# Out:
# {'algo': {'submissionId': 'b7b6ce35-5326-46cc-9f84-f2db9b883930', 'summary': {'round': 'ROUND1_ALGO', 'handler': None, 'status': 'FINISHED', 'score': None, 'profit': 1502.96, 'activitiesLog': 'https://imcprosperityapiendpoint-roundresultsbucket0d21da-jovk2fj2enau.s3.eu-west-1.amazonaws.com/b7b6ce35-5326-46cc-9f84-f2db9b883930.csv?AWSAccessKeyId=ASIAVHMHB3Q6QWUW3VUC&Expires=1679397620&Signature=OfDl1WXVv7e6T%2FvNPG0l5DUvEIM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEMP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCWV1LXdlc3QtMSJHMEUCIQCjmneCpYDqUaIel4wvXP0E25Ln%2FEwrQ4lSIzHHL3PV%2FQIgBvHNIDI%2B%2BqT%2FQGLQH%2FuQ0D8iBe0yTvE9rsvrBn88Hkoq1AMIjP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARABGgwzNTk0NDk4Nzc1NjUiDC0U8%2BULtIpsOGxu5iqoAwIznAQ9tttM9DXj5fYD1fyIjTbq3Q%2B4kHQPrJP0QXE%2Bjpn%2BoQzSULUgQKrV0ZwGIwMLFyv7ytU8GdtuCsxTZ8Z%2BGytI1UrplN%2Bh9Kdq4gs9sGcuJJPdng7ds7blylOuCaWXZoynKyPl%2FfFYiUlDhRoLHjs3%2FOtdoQm1b4%2BtRb0MYzbNLYHh54lw1KIZgi8YhQ1axKSsAdoIfmoxDqYB4wTA7U0YiKkgvL1Ra%2FcrCxy2dwnvHBWk5xg%2BmUI5qRemoWlgc6OBiJfZP
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
spread = 1
plt.rcParams['savefig.facecolor'] = 'white'
data = r.json()
pnl = data['algo']['profitAndLoss']
x = [int(i['timestamp'])for i in pnl]
y = [float(i['value']) for i in pnl]
# plt.figure(figsize=(18, 9))
plt.plot(x,y)
plt.title(f"Pearl Only, Default Spread = {spread}")
plt.xlabel('Time')
plt.ylabel('PnL')
plt.show()
plt.savefig(f"plots/round1/basic_model_pearl_only_spread_{spread}.png", dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\chris\Downloads\tester.ipynb Cell 3 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Downloads/tester.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> plt.ylabel('PnL')
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Downloads/tester.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> plt.show()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chris/Downloads/tester.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> plt.savefig(f"plots/round1/basic_model_pearl_only_spread_{spread}.png", dpi=300, bbox_inches='tight')
#
# File c:\Users\chris\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
# ...
